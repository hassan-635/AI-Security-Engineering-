# %%
import numpy as np

# %%
a = np.array([1,2,3])
print(a)

b = np.array([[1,2,3],
              [4,5,6]])
print(b)
# Out:
# [1 2 3]
# [[1 2 3]
#  [4 5 6]]

# %%
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# # array addition
