# %%
# import libraries

import numpy as np

# %% [markdown]
# # libraries install

# %%
# !pip install numpy
# Out:
# ...
#      -------------------------------------- 12.6/12.6 MB 836.6 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
